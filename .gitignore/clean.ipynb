# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# Show all columns when displaying DataFrames
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'data/raw/chicago_crime_2001_2025.csv')

# %%
# Ensure 'Date' column is datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Extract year
df['Year'] = df['Date'].dt.year

# Group by Year and Primary Type, then count
yearly_counts = df.groupby(['Year', 'Primary Type']).size().reset_index(name='Count')

# Pivot to get Years as index, Crime Types as columns
crime_pivot = yearly_counts.pivot(index='Year', columns='Primary Type', values='Count').fillna(0).astype(int)

# View the result
crime_pivot.head()
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Year
# 2001           1011    31380    93445     26003
# 2002            944    28764    85544     22836
# 2003             10      227      822       229
# 2004              3       46       96        20
# 2005              0       49      113        23
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Year
# 2001                                          1                 1683
# 2002                                          0                 1516
# 2003                                          0                   19
# 2004                                          0                    7
# 2005                                          0                    7
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  \
# Year
# 2001                    55843                       25              13237
# 2002                    50640                       26              12607
# 2003                      519                        4                133
# 2004                        9                        8                  3
# 2005                       22                        6                  7
#
# Primary Type  DECEPTIVE PRACTICE  DOMESTIC VIOLENCE  GAMBLING  HOMICIDE  \
# Year
# 2001                       14740                  1       934       667
# 2002                       11613                  0       887       656
# 2003                          69                  0         1       598
# 2004                          12                  0         0       454
# 2005                          29                  0         1       451
#
# Primary Type  HUMAN TRAFFICKING  INTERFERENCE WITH PUBLIC OFFICER  \
# Year
# 2001                          0                               405
# 2002                          0                               322
# 2003                          0                                 5
# 2004                          0                                 1
# 2005                          0                                 1
#
# Primary Type  INTIMIDATION  KIDNAPPING  LIQUOR LAW VIOLATION  \
# Year
# 2001                   278         933                  1636
# 2002                   297         748                  1246
# 2003                     4           6                     0
# 2004                     0           0                     0
# 2005                     0           0                     1
#
# Primary Type  MOTOR VEHICLE THEFT  NARCOTICS  NON-CRIMINAL  OBSCENITY  \
# Year
# 2001                        27541      50554             0         19
# 2002                        22568      46367             0         22
# 2003                          225         21             0          0
# 2004                            6         10             0          0
# 2005                           14         39             0          0
#
# Primary Type  OFFENSE INVOLVING CHILDREN  OTHER NARCOTIC VIOLATION  \
# Year
# 2001                                2064                         6
# 2002                                2029                         4
# 2003                                  24                         0
# 2004                                  20                         0
# 2005                                  18                         0
#
# Primary Type  OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# Year
# 2001                  29610          6025                 9
# 2002                  29098          5724                 7
# 2003                    309             2                 0
# 2004                     10             1                 0
# 2005                     32             2                 0
#
# Primary Type  PUBLIC PEACE VIOLATION  RITUALISM  ROBBERY  SEX OFFENSE  \
# Year
# 2001                            2748          8    18438         2112
# 2002                            2257          2    16592         1853
# 2003                              16          0      236           16
# 2004                               3          0        4            5
# 2005                               1          0       34            7
#
# Primary Type  STALKING  THEFT  WEAPONS VIOLATION
# Year
# 2001               203  98419               4273
# 2002               173  86500               3887
# 2003                 3    839                 48
# 2004                 1    150                  2
# 2005                 0    181                  2

# %%
#save the cleaned DataFrame to a new CSV file
crime_pivot.to_csv('../data/crime_pivot.csv')

# %%
df.head()
# Out:
#          ID Case Number             Date                    Block  IUCR  \
# 0  13311263    JG503434   7/29/2022 3:39          023XX S TROY ST  1582
# 1  13053066    JG103252   1/3/2023 16:44  039XX W WASHINGTON BLVD  2017
# 2  11227634    JB147599  8/26/2017 10:00      001XX W RANDOLPH ST   281
# 3  13203321    JG415333   9/6/2023 17:00         002XX N Wells st  1320
# 4  13204489    JG416325   9/6/2023 11:00           0000X E 8TH ST   810
#
#                  Primary Type                    Description  \
# 0  OFFENSE INVOLVING CHILDREN              CHILD PORNOGRAPHY
# 1                   NARCOTICS  MANUFACTURE / DELIVER - CRACK
# 2         CRIM SEXUAL ASSAULT                 NON-AGGRAVATED
# 3             CRIMINAL DAMAGE                     TO VEHICLE
# 4                       THEFT                      OVER $500
#
#                      Location Description  Arrest  Domestic  Beat  District  \
# 0                               RESIDENCE    True     False  1033        10
# 1                                SIDEWALK    True     False  1122        11
# 2                             HOTEL/MOTEL   False     False   122         1
# 3  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   122         1
# 4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False   123         1
#
#    Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0  25.0            30.0       17           NaN           NaN  2022
# 1  28.0            26.0       18           NaN           NaN  2023
# 2  42.0            32.0        2           NaN           NaN  2017
# 3  42.0            32.0       14     1174694.0     1901831.0  2023
# 4   4.0            32.0        6     1176857.0     1896680.0  2023
#
#         Updated On   Latitude  Longitude                       Location
# 0  4/18/2024 15:40        NaN        NaN                            NaN
# 1  1/20/2024 15:41        NaN        NaN                            NaN
# 2  2/11/2018 15:57        NaN        NaN                            NaN
# 3  11/4/2023 15:40  41.886018 -87.633938  (41.886018055, -87.633937881)
# 4  11/4/2023 15:40  41.871835 -87.626151   (41.871834768, -87.62615082)

# %%
# Create a copy of the original DataFrame to preserve it
df_cleaned = df.copy()

# %%
#remove columns that are not needed for analysis
columns_to_drop = ['ID', 'Case Number', 'Block', 'IUCR', 'Location Description', 'Domestic', 'Beat', 'District', 'Community Area', 'FBI Code', 'Updated On', 'Location', 'X Coordinate', 'Y Coordinate', 'Updated On', 'Domestic',]
df_cleaned.drop(columns=columns_to_drop, inplace=True)
df_cleaned.head()
# Out:
#               Date                Primary Type                    Description  \
# 0   7/29/2022 3:39  OFFENSE INVOLVING CHILDREN              CHILD PORNOGRAPHY
# 1   1/3/2023 16:44                   NARCOTICS  MANUFACTURE / DELIVER - CRACK
# 2  8/26/2017 10:00         CRIM SEXUAL ASSAULT                 NON-AGGRAVATED
# 3   9/6/2023 17:00             CRIMINAL DAMAGE                     TO VEHICLE
# 4   9/6/2023 11:00                       THEFT                      OVER $500
#
#    Arrest  Ward  X Coordinate  Y Coordinate  Year   Latitude  Longitude
# 0    True  25.0           NaN           NaN  2022        NaN        NaN
# 1    True  28.0           NaN           NaN  2023        NaN        NaN
# 2   False  42.0           NaN           NaN  2017        NaN        NaN
# 3   False  42.0     1174694.0     1901831.0  2023  41.886018 -87.633938
# 4   False   4.0     1176857.0     1896680.0  2023  41.871835 -87.626151

# %%
#df memory usage
df_cleaned.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Date          1048575 non-null  object
#  1   Primary Type  1048575 non-null  object
#  2   Description   1048575 non-null  object
#  3   Arrest        1048575 non-null  bool
#  4   Ward          433886 non-null   float64
#  5   X Coordinate  1024903 non-null  float64
#  6   Y Coordinate  1024903 non-null  float64
#  7   Year          1048575 non-null  int64
#  8   Latitude      1024903 non-null  float64
#  9   Longitude     1024903 non-null  float64
# dtypes: bool(1), float64(5), int64(1), object(3)
# memory usage: 235.5 MB
